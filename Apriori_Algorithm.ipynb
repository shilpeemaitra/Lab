# %% [markdown]
# <a href="https://colab.research.google.com/github/shilpeemaitra/Lab/blob/main/Apriori_Algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
data= pd.read_csv('/content/Groceries_dataset - Groceries_dataset.csv')

# %%
data.shape
# Out:
# (38765, 3)

# %%
data
# Out:
#        Member_number        Date        itemDescription
# 0               1808  21-07-2015         tropical fruit
# 1               2552  05-01-2015             whole milk
# 2               2300  19-09-2015              pip fruit
# 3               1187  12-12-2015       other vegetables
# 4               3037  01-02-2015             whole milk
# ...              ...         ...                    ...
# 38760           4471  08-10-2014          sliced cheese
# 38761           2022  23-02-2014                  candy
# 38762           1097  16-04-2014               cake bar
# 38763           1510  03-12-2014  fruit/vegetable juice
# 38764           1521  26-12-2014               cat food
#
# [38765 rows x 3 columns]

# %% [markdown]
# Notes: display top  10 values in descending order of the no. of times it was bought

# %%
x= data['itemDescription'].value_counts().sort_values(ascending=False)[:10]

# %%
x
# Out:
# whole milk          2502
# other vegetables    1898
# rolls/buns          1716
# soda                1514
# yogurt              1334
# root vegetables     1071
# tropical fruit      1032
# bottled water        933
# sausage              924
# citrus fruit         812
# Name: itemDescription, dtype: int64

# %% [markdown]
# x= item name
# y= no. of purchases

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=x.index, y=x.values)
plt.show()

# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
data['Quantity']=1

# %%
data
# Out:
#        Member_number        Date        itemDescription  Quantity
# 0               1808  21-07-2015         tropical fruit         1
# 1               2552  05-01-2015             whole milk         1
# 2               2300  19-09-2015              pip fruit         1
# 3               1187  12-12-2015       other vegetables         1
# 4               3037  01-02-2015             whole milk         1
# ...              ...         ...                    ...       ...
# 38760           4471  08-10-2014          sliced cheese         1
# 38761           2022  23-02-2014                  candy         1
# 38762           1097  16-04-2014               cake bar         1
# 38763           1510  03-12-2014  fruit/vegetable juice         1
# 38764           1521  26-12-2014               cat food         1
#
# [38765 rows x 4 columns]

# %%
transaction= data.groupby(['Member_number','itemDescription'])['Quantity'].sum().unstack().reset_index().set_index('Member_number')

# %%
transaction
# Out:
# itemDescription  Instant food products  UHT-milk  abrasive cleaner  \
# Member_number
# 1000                               NaN       NaN               NaN
# 1001                               NaN       NaN               NaN
# 1002                               NaN       NaN               NaN
# 1003                               NaN       NaN               NaN
# 1004                               NaN       NaN               NaN
# ...                                ...       ...               ...
# 4996                               NaN       NaN               NaN
# 4997                               NaN       NaN               NaN
# 4998                               NaN       NaN               NaN
# 4999                               NaN       NaN               NaN
# 5000                               NaN       NaN               NaN
#
# itemDescription  artif. sweetener  baby cosmetics  bags  baking powder  \
# Member_number
# ...

# %%
transaction= transaction.fillna(0)

# %%
transaction
# Out:
# itemDescription  Instant food products  UHT-milk  abrasive cleaner  \
# Member_number
# 1000                               0.0       0.0               0.0
# 1001                               0.0       0.0               0.0
# 1002                               0.0       0.0               0.0
# 1003                               0.0       0.0               0.0
# 1004                               0.0       0.0               0.0
# ...                                ...       ...               ...
# 4996                               0.0       0.0               0.0
# 4997                               0.0       0.0               0.0
# 4998                               0.0       0.0               0.0
# 4999                               0.0       0.0               0.0
# 5000                               0.0       0.0               0.0
#
# itemDescription  artif. sweetener  baby cosmetics  bags  baking powder  \
# Member_number
# ...

# %%
def encode(x):
  if x<=0:
    return 0
  elif x>=0:
    return 1
basket = transaction.applymap(encode)

# %%
basket
# Out:
# itemDescription  Instant food products  UHT-milk  abrasive cleaner  \
# Member_number
# 1000                                 0         0                 0
# 1001                                 0         0                 0
# 1002                                 0         0                 0
# 1003                                 0         0                 0
# 1004                                 0         0                 0
# ...                                ...       ...               ...
# 4996                                 0         0                 0
# 4997                                 0         0                 0
# 4998                                 0         0                 0
# 4999                                 0         0                 0
# 5000                                 0         0                 0
#
# itemDescription  artif. sweetener  baby cosmetics  bags  baking powder  \
# Member_number
# ...

# %%
frequent_itemset=apriori(basket,min_support=0.06, use_colnames=True)
rules=association_rules(frequent_itemset,metric='lift',min_threshold=1)

# %%
rules.head()
# Out:
#           antecedents         consequents  antecedent support  \
# 0        (whole milk)              (beef)            0.458184
# 1              (beef)        (whole milk)            0.119548
# 2  (other vegetables)      (bottled beer)            0.376603
# 3      (bottled beer)  (other vegetables)            0.158799
# 4        (rolls/buns)      (bottled beer)            0.349666
#
#    consequent support   support  confidence      lift  leverage  conviction  \
# 0            0.119548  0.064135    0.139978  1.170886  0.009360    1.023754
# 1            0.458184  0.064135    0.536481  1.170886  0.009360    1.168919
# 2            0.158799  0.068497    0.181880  1.145345  0.008692    1.028212
# 3            0.376603  0.068497    0.431341  1.145345  0.008692    1.096257
# 4            0.158799  0.063109    0.180484  1.136555  0.007582    1.026461
#
#    zhangs_metric
# 0       0.269364
# 1       0.165762
# 2       0.203563
# 3       0.150857
# 4       0.184748

# %% [markdown]
# Lift= confidence of 2 items/support of the item
#
# lift>1 then strong association else no correlation

# %%
a=rules['lift'].sort_values(ascending=False)[:10]

# %%
rules.sort_values(['lift','confidence'],ascending=False)[:10]
# Out:
#                         antecedents                     consequents  \
# 144                        (yogurt)  (whole milk, other vegetables)
# 141  (whole milk, other vegetables)                        (yogurt)
# 153        (whole milk, rolls/buns)                        (yogurt)
# 156                        (yogurt)        (whole milk, rolls/buns)
# 143                    (whole milk)      (yogurt, other vegetables)
# 142      (yogurt, other vegetables)                    (whole milk)
# 108                       (sausage)                        (yogurt)
# 109                        (yogurt)                       (sausage)
# 154            (yogurt, rolls/buns)                    (whole milk)
# 155                    (whole milk)            (yogurt, rolls/buns)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 144            0.282966            0.191380  0.071832    0.253853  1.326434
# ...

# %%
best_choice= rules.sort_values(by='lift', ascending =True)
print('best choice would be')
print(best_choice[['antecedents','consequents','lift']])
# Out:
# best choice would be
#                         antecedents                     consequents      lift
# 63                 (tropical fruit)              (other vegetables)  1.037642
# 62               (other vegetables)                (tropical fruit)  1.037642
# 61               (other vegetables)                          (soda)  1.051695
# 60                           (soda)              (other vegetables)  1.051695
# 116                    (whole milk)                          (soda)  1.051973
# ..                              ...                             ...       ...
# 143                    (whole milk)      (yogurt, other vegetables)  1.303003
# 156                        (yogurt)        (whole milk, rolls/buns)  1.304939
# 153        (whole milk, rolls/buns)                        (yogurt)  1.304939
# 141  (whole milk, other vegetables)                        (yogurt)  1.326434
# 144                        (yogurt)  (whole milk, other vegetables)  1.326434
#
# ...
